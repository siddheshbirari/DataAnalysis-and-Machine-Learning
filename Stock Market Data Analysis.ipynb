# %%
#normal imports
import pandas as pd
from pandas import DataFrame,Series
import numpy as np

# %%
#Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import pandas_datareader as pdr

# %%
pip install datetime
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import division

# %%
tech_list = ['AAPL','GOOG','MSFT','AMZN']

# %%
tech_list
# Out:
# ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
end = datetime.now()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8bdbc53eb39e> in <module>
# ----> 1 end = datetime.now()
#
# NameError: name 'datetime' is not defined

# %%
from datetime import datetime

# %%
end = datetime.now()

# %%
end
# Out:
# datetime.datetime(2020, 3, 25, 21, 47, 59, 105960)

# %%
start = datetime(end.year-1,end.month,end.day) #1 year bac from todays date

# %%
yahoo_df = pdr.get_data_yahoo('AAPL',start,end)

# %%
yahoo_df #this was sample
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-03-26  192.880005  184.580002  191.660004  186.789993   49800500.0
# 2019-03-27  189.759995  186.550003  188.750000  188.470001   29848400.0
# 2019-03-28  189.559998  187.529999  188.949997  188.720001   20780400.0
# 2019-03-29  190.080002  188.539993  189.830002  189.949997   23564000.0
# 2019-04-01  191.679993  188.380005  191.639999  191.240005   27862000.0
# ...                ...         ...         ...         ...          ...
# 2020-03-20  251.830002  228.000000  247.179993  229.240005  100423300.0
# 2020-03-23  228.500000  212.610001  228.080002  224.369995   84188200.0
# 2020-03-24  247.690002  234.300003  236.360001  246.880005   71882800.0
# 2020-03-25  258.250000  244.300003  250.750000  245.520004   75763700.0
# 2020-03-26  258.660004  246.360001  246.520004  258.440002   60316500.0
#
#              Adj Close
# Date
# 2019-03-26  184.376678
# 2019-03-27  186.034973
# ...

# %%
tech_list
# Out:
# ['AAPL', 'GOOG', 'MSFT', 'AMZN']

# %%
for stock in tech_list:
    globals()[stock] = pdr.get_data_yahoo(stock,start,end) #this is creating individual dataframe for each stock in list

# %%
AAPL
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2019-03-25  191.979996  186.600006  191.509995  188.740005   43845300.0
# 2019-03-26  192.880005  184.580002  191.660004  186.789993   49800500.0
# 2019-03-27  189.759995  186.550003  188.750000  188.470001   29848400.0
# 2019-03-28  189.559998  187.529999  188.949997  188.720001   20780400.0
# 2019-03-29  190.080002  188.539993  189.830002  189.949997   23564000.0
# ...                ...         ...         ...         ...          ...
# 2020-03-19  252.839996  242.610001  247.389999  244.779999   67964300.0
# 2020-03-20  251.830002  228.000000  247.179993  229.240005  100423300.0
# 2020-03-23  228.500000  212.610001  228.080002  224.369995   84188200.0
# 2020-03-24  247.690002  234.300003  236.360001  246.880005   71882800.0
# 2020-03-25  258.250000  244.300003  250.750000  245.520004   75763700.0
#
#              Adj Close
# Date
# 2019-03-25  186.301483
# 2019-03-26  184.376678
# ...

# %%
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   239.719370  234.640512  236.898976  237.387992  3.202027e+07
# std     44.246374   42.983171   43.456970   43.811916  1.714349e+07
# min    177.919998  170.270004  175.440002  173.300003  1.136200e+07
# 25%    203.579998  199.872498  201.520004  201.959999  2.117318e+07
# 50%    222.525002  217.689995  220.719994  220.760002  2.672145e+07
# 75%    270.949997  265.370010  267.427505  268.320007  3.509805e+07
# max    327.850006  323.350006  324.739990  327.200012  1.067212e+08
#
#         Adj Close
# count  254.000000
# mean   236.145540
# std     44.401927
# min    171.719727
# 25%    200.248940
# 50%    219.578079
# 75%    267.684708
# max    327.200012

# %%
GOOG
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-03-25  1206.397949  1187.040039  1196.930054  1193.000000  1496800
# 2019-03-26  1202.829956  1176.719971  1198.530029  1184.619995  1901200
# 2019-03-27  1187.558960  1159.369995  1185.500000  1173.020020  1400200
# 2019-03-28  1171.564941  1159.431030  1171.540039  1168.489990  1012400
# 2019-03-29  1178.989990  1162.880005  1174.900024  1173.310059  1269900
# ...                 ...          ...          ...          ...      ...
# 2020-03-19  1157.969971  1060.108032  1093.050049  1115.290039  3651100
# 2020-03-20  1143.989990  1065.489990  1135.719971  1072.319946  3601800
# 2020-03-23  1071.319946  1013.536011  1061.319946  1056.619995  4044100
# 2020-03-24  1135.000000  1090.619995  1103.770020  1134.459961  3344500
# 2020-03-25  1148.900024  1086.010010  1126.469971  1102.489990  4076400
#
#               Adj Close
# Date
# 2019-03-25  1193.000000
# 2019-03-26  1184.619995
# ...

# %%
AAPL.describe()
# Out:
#              High         Low        Open       Close        Volume  \
# count  254.000000  254.000000  254.000000  254.000000  2.540000e+02
# mean   239.719370  234.640512  236.898976  237.387992  3.202027e+07
# std     44.246374   42.983171   43.456970   43.811916  1.714349e+07
# min    177.919998  170.270004  175.440002  173.300003  1.136200e+07
# 25%    203.579998  199.872498  201.520004  201.959999  2.117318e+07
# 50%    222.525002  217.689995  220.719994  220.760002  2.672145e+07
# 75%    270.949997  265.370010  267.427505  268.320007  3.509805e+07
# max    327.850006  323.350006  324.739990  327.200012  1.067212e+08
#
#         Adj Close
# count  254.000000
# mean   236.145540
# std     44.401927
# min    171.719727
# 25%    200.248940
# 50%    219.578079
# 75%    267.684708
# max    327.200012

# %%
AAPL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2019-03-25 to 2020-03-25
# Data columns (total 6 columns):
# High         254 non-null float64
# Low          254 non-null float64
# Open         254 non-null float64
# Close        254 non-null float64
# Volume       254 non-null float64
# Adj Close    254 non-null float64
# dtypes: float64(6)
# memory usage: 13.9 KB

# %%
#Historical view of closing price

AAPL['Adj Close'].plot(legend=True,figsize = (10,4))

# %%
AAPL['Volume'].plot(legend=True,figsize=(10,4))

# %%
#moving averages for Apple stock

#several moving averages

ma_day = [10,20,50] #number of days of moving average

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    AAPL[column_name] = pd.Series(AAPL['Adj Close']).rolling(window=24).mean() #this can be done via pd.rolling_mean as well

# %%
AAPL[['Adj Close','MA for 10 days','MA for 20 days','MA for 50 days']].plot(subplots =False,figsize=(10,4))

# %%
#making new column
AAPL['Daily Return'] = AAPL['Adj Close'].pct_change() #% change for each day

AAPL['Daily Return'].plot(figsize=(10,4),legend=True,linestyle='--',marker='o') #figsize is in inches 10inch * 4 inch

# %%
sns.distplot(AAPL['Daily Return'].dropna(),bins=100,color='purple') #distplot allows to plot different plots on each other

# %%
AAPL['Daily Return'].hist(bins=100) #some of the plotting methods are pandas builtin, but you can use seaborn as well for additional functionality

# %%
#returns of stocks

#yahoo_df = pdr.get_data_yahoo('AAPL',start,end)

closing_df = pdr.get_data_yahoo(tech_list,start,end) ['Adj Close']

# %%
closing_df.head()
# Out:
# Symbols           AAPL         GOOG        MSFT         AMZN
# Date
# 2019-03-25  186.301483  1193.000000  116.123627  1774.260010
# 2019-03-26  184.376678  1184.619995  116.370346  1783.760010
# 2019-03-27  186.034973  1173.020020  115.245224  1765.699951
# 2019-03-28  186.281738  1168.489990  115.403145  1773.420044
# 2019-03-29  187.495865  1173.310059  116.399963  1780.750000

# %%
tech_rets = closing_df.pct_change()

# %%
tech_rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-03-25       NaN       NaN       NaN       NaN
# 2019-03-26 -0.010332 -0.007024  0.002125  0.005354
# 2019-03-27  0.008994 -0.009792 -0.009668 -0.010125
# 2019-03-28  0.001326 -0.003862  0.001370  0.004372
# 2019-03-29  0.006518  0.004125  0.008638  0.004133

# %%
#comparing google to itself

sns.jointplot('GOOG','GOOG',tech_rets,kind='scatter',color='seagreen')

# %%
#compare 2 different stocks

sns.jointplot('GOOG','MSFT',tech_rets,kind='scatter')

# %%
tech_rets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 254 entries, 2019-03-25 to 2020-03-25
# Data columns (total 4 columns):
# AAPL    253 non-null float64
# GOOG    253 non-null float64
# MSFT    253 non-null float64
# AMZN    253 non-null float64
# dtypes: float64(4)
# memory usage: 9.9 KB

# %%
from IPython.display import SVG
SVG(url='https://commons.wikimedia.org/wiki/File:Correlation_examples2.svg')

# %%
#comaprision analysis plot using pair plot

tech_rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-03-26       NaN       NaN       NaN       NaN
# 2019-03-27  0.008994 -0.009792 -0.009668 -0.010125
# 2019-03-28  0.001326 -0.003862  0.001370  0.004372
# 2019-03-29  0.006518  0.004125  0.008638  0.004133
# 2019-04-01  0.006791  0.018000  0.009157  0.018779

# %%
sns.pairplot(tech_rets.dropna())

# %%
#We can control pairplot using pairgrid..

returns_fig = sns.PairGrid(tech_rets.dropna())

returns_fig.map_upper(plt.scatter,color='purple') # upper rectangle

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist,bins=30)

# %%
#We can control pairplot using pairgrid..

returns_fig = sns.PairGrid(closing_df)

returns_fig.map_upper(plt.scatter,color='purple') # upper rectangle

returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

returns_fig.map_diag(plt.hist,bins=30)

# %%
sns.heatmap(tech_rets.dropna(),annot=True) #corrplot is not available hence using heatmap for this.sns.

# %%
sns.heatmap(closing_df,annot=True) #google and amazon has strongest corelation

# %%
#Risk Analysis comapring standard daviation of daily returns vs expected returns or average daily return

rets = tech_rets.dropna()

# %%
rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-03-27  0.008994 -0.009792 -0.009668 -0.010125
# 2019-03-28  0.001326 -0.003862  0.001370  0.004372
# 2019-03-29  0.006518  0.004125  0.008638  0.004133
# 2019-04-01  0.006791  0.018000  0.009157  0.018779
# 2019-04-02  0.014537  0.005073  0.001428 -0.000116

# %%
area = np.pi*20

plt.scatter(rets.mean(),rets.std(),s = area)

plt.xlabel('Expected Return')

plt.ylabel('Risk')

for label,x,y in zip(rets.columns,rets.mean(),rets.std()): #zip allows columns to be called at once
    plt.annotate(
    label,
    xy = (x,y),xytext = (50,50),
    textcoords = 'offset points',ha = 'right', va = 'bottom',
    arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %%
#value at risk

#bootstrap method for calculation of value at risk

sns.distplot(AAPL['Daily Return'].dropna(),bins=100,color='purple')

# %%
#use quantiles

rets.head()
# Out:
# Symbols         AAPL      GOOG      MSFT      AMZN
# Date
# 2019-03-27  0.008994 -0.009792 -0.009668 -0.010125
# 2019-03-28  0.001326 -0.003862  0.001370  0.004372
# 2019-03-29  0.006518  0.004125  0.008638  0.004133
# 2019-04-01  0.006791  0.018000  0.009157  0.018779
# 2019-04-02  0.014537  0.005073  0.001428 -0.000116

# %%
rets['AAPL'].quantile(0.05) #learn this concept mathematically, output says 95% of time you will not loose more than 3.2% for apple "Stock Market Data Analysis.ipynb"k
# Out:
# -0.03203036737004463

# %%
#value of risk using Monte Carlo Method. Need to learn this method mathematically

#time horizon

days = 365

dt = 1/days

mu = rets.mean()['GOOG']

sigma = rets.std()['GOOG']

# %%
sigma
# Out:
# 0.02118083217687593

# %%
mu
# Out:
# 0.00014775412312052207

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
    
    price = np.zeros(days)
    price[0] = start_price
    
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    
    for x in range(1,days):
        shock[x] = np.random.normal(loc=mu*dt,scale = sigma*np.sqrt(dt))
        drift[x] = mu * dt
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
   
    return price

# %%
GOOG.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2019-03-26  1202.829956  1176.719971  1198.530029  1184.619995  1901200
# 2019-03-27  1187.558960  1159.369995  1185.500000  1173.020020  1400200
# 2019-03-28  1171.564941  1159.431030  1171.540039  1168.489990  1012400
# 2019-03-29  1178.989990  1162.880005  1174.900024  1173.310059  1269900
# 2019-04-01  1196.660034  1182.000000  1184.099976  1194.430054  1252500
#
#               Adj Close
# Date
# 2019-03-26  1184.619995
# 2019-03-27  1173.020020
# 2019-03-28  1168.489990
# 2019-03-29  1173.310059
# 2019-04-01  1194.430054

# %%
start_price = 1198.53

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
    
plt.xlabel('Days')
plt.ylabel('Price')
plt.title('Monte Carlo Analysis for Google')
# Out:
# Text(0.5, 1.0, 'Monte Carlo Analysis for Google')

# %% [raw]
# runs = 10000

# %%
runs = 10000

simulations = np.zeros(runs)

for run in range(runs):
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1]

# %%
simulations
# Out:
# array([1201.47164932, 1206.12726423, 1128.48865497, ..., 1195.82308291,
#        1203.12273172, 1210.67576714])

# %%
q = np.percentile(simulations,1)

plt.hist(simulations,bins=200)

#Starting Price
plt.figtext(0.6,0.8, s = "Start Price: $%.2f" %start_price)

#Mean Ending price

plt.figtext(0.6,0.7, "Mean final price: $%.2f" % simulations.mean())

#Variance of the price (within 99% confidence interval)

plt.figtext(0.15,0.6,"Var(0.99):$%.2f" %q)

#Plot 1% quantile

plt.figtext(0.15,0.6,"q(0.99):$%2.f" % q)

#plot a line at the 1% quantile result

plt.axvline(x=q,linewidth=4,color='r')

#Title
plt.title(u"Final price distribution for Google tock after %s days" % days,weight='bold')
# Out:
# Text(0.5, 1.0, 'Final price distribution for Google tock after 365 days')
